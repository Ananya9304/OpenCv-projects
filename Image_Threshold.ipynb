# %% [markdown]
# <a href="https://colab.research.google.com/github/Ananya9304/OpenCv-projects/blob/main/Image_Threshold.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
img = cv2.imread("/content/flower.jpg")

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=174x180>

# %%
img2=cv2.imread("/content/flower.jpg",0)
from google.colab.patches import cv2_imshow
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=L size=174x180>

# %%
cv2.imwrite('save_img.png',img2)
# Out:
# True
